# %% [markdown]
# # Lab | Data Aggregation and Filtering

# %% [markdown]
# Objective: Use Python programming techniques to filter and order data subsets, group data by one or more variables, and use aggregation functions to obtain insights, and derive meaningful conclusions from the data.

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company. We will use the dataset called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing first data cleaning, formatting, and structuring.

# %% [markdown]
# Start by reading the dataset, standardizing column names, dealing with null values and creating the month column. You can do so by using the functions you developed in previous labs, or by reading the clean dataset you saved in the last lab `data structuring and combining`.

# %% [markdown]
# Then, answer the following questions:

# %% [markdown]
# 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign.

# %% [markdown]
# 2. Analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign.

# %% [markdown]
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %% [markdown]
# 4. Find the median customer lifetime value by education level and gender.

# %% [markdown]
# 5. Find the maximum, minimum, and average number of open complaints by state and policy type.

# %% [markdown]
# 6. The marketing team wants to analyze the number of policies sold by state and month.
#
# Present the data in a table where the months are arranged as columns and the states are arranged as rows.

# %% [markdown]
# 7. Display a new DataFrame that contains the number of policies sold by month by state for the top 3 states with the highest number of policies sold.
#
# *Hint:*
# - *To accomplish this, you will first need to group the data by state and month, then count the number of policies sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order.*
# - *Next, you will select the top 3 states with the highest number of policies sold.*
# - *Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.*

# %% [markdown]
# 8. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
#
# Hint: You can use melt to unpivot the data and create a table that shows the customer response rate (those who responded "Yes") by marketing channel.

# %% [markdown]
# External Resources for Data Filtering: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('mca_data_clean.csv', sep=';') # load data
df
# Out:
#       unnamed:_0 customer       state  customer_lifetime_value response  \
# 0              2  LZ68649  Washington             14947.917300       No
# 1              3  XL78013      Oregon             22332.439460      Yes
# 2             10  HG93801     Arizona              5154.764074       No
# 3             13  KR82385  California              5454.587929       No
# 4             16  FH51383  California              5326.677654       No
# ...          ...      ...         ...                      ...      ...
# 4538       10902  PP30874  California              3579.023825       No
# 4539       10903  SU71163     Arizona              2771.663013       No
# 4540       10904  QI63521      Nevada             19228.463620       No
# 4541       10906  KX53892      Oregon              5259.444853       No
# 4542       10908  WA60547  California             11971.977650       No
#
#       coverage             education effective_to_date employmentstatus  \
# 0        Basic              Bachelor        2011-02-10         Employed
# 1     Extended               College        2011-01-11         Employed
# 2     Extended  High School or Below        2011-01-02         Employed
# 3        Basic                Master        2011-01-26         Employed
# 4        Basic  High School or Below        2011-02-07         Employed
# ...        ...                   ...               ...              ...
# 4538  Extended  High School or Below        2011-01-24         Employed
# 4539     Basic               College        2011-01-07         Employed
# 4540     Basic  High School or Below        2011-02-24       Unemployed
# 4541     Basic               College        2011-01-06         Employed
# 4542   Premium               College        2011-02-13         Employed
#
#      gender  ...  number_of_policies     policy_type        policy  \
# 0         M  ...                   2   Personal Auto   Personal L3
# 1         M  ...                   2  Corporate Auto  Corporate L3
# 2         M  ...                   1  Corporate Auto  Corporate L3
# 3         M  ...                   4   Personal Auto   Personal L3
# 4         F  ...                   6   Personal Auto   Personal L3
# ...     ...  ...                 ...             ...           ...
# 4538      F  ...                   1   Personal Auto   Personal L2
# 4539      M  ...                   1   Personal Auto   Personal L2
# 4540      M  ...                   2   Personal Auto   Personal L2
# 4541      F  ...                   6   Personal Auto   Personal L3
# 4542      F  ...                   6   Personal Auto   Personal L1
#
#       renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0               Offer3    Call Center          480.000000            SUV
# 1               Offer2         Branch          484.013411  Four-Door Car
# 2               Offer2         Branch          442.521087            SUV
# 3               Offer4    Call Center          331.200000   Two-Door Car
# 4               Offer4    Call Center          300.528579   Two-Door Car
# ...                ...            ...                 ...            ...
# 4538            Offer2          Agent          655.200000  Four-Door Car
# 4539            Offer2         Branch          355.200000   Two-Door Car
# 4540            Offer1         Branch          897.600000     Luxury SUV
# 4541            Offer2         Branch          273.018929  Four-Door Car
# 4542            Offer1         Branch          618.288849            SUV
#
#       vehicle_size vehicle_type effective_to_date_month
# 0          Medsize            A                       2
# 1          Medsize            A                       1
# 2            Large            A                       1
# 3          Medsize            A                       1
# 4            Large            A                       2
# ...            ...          ...                     ...
# 4538       Medsize            A                       1
# 4539       Medsize            A                       1
# 4540       Medsize            A                       2
# 4541       Medsize            A                       1
# 4542       Medsize            A                       2
#
# [4543 rows x 27 columns]

# %%
# 1. total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign
df1 = df[ (df['total_claim_amount'] > 1000) & (df['response'] == 'Yes')]
df1.shape
# Out:
# (27, 27)

# %%
# 2. Analyze average total_claim_amount by each policy type and gender with response = Yes

df2 = df[ df['response'] == 'Yes'].groupby(['policy_type','gender']).agg({'total_claim_amount':'mean'}).rename(columns={'total_claim_amount': 'mean_total_claim_amount'})

df2
# Out:
#                        mean_total_claim_amount
# policy_type    gender
# Corporate Auto F                    404.104008
#                M                    391.370774
# Personal Auto  F                    457.056315
#                M                    472.489180
# Special Auto   F                    495.689401
#                M                    368.523035

# %%
# 3. total customers who have policies in each state, states where there are more than 500 customers.

df3 = df.groupby(['state']).agg({'customer':'count'}).rename(columns = {'customer':'number_of_customers'})
df3 = df3[df3['number_of_customers'] > 500]
df3
# Out:
#             number_of_customers
# state
# Arizona                     868
# California                 1552
# Oregon                     1281

# %%
# 4. Find the median customer lifetime value by education level and gender.
df4 = df.groupby(['education', 'gender']).agg({'customer_lifetime_value': 'median'}).round(2).rename(columns={'customer_lifetime_value':'median_customer_lifetime_value'})
df4
# Out:
#                              median_customer_lifetime_value
# education            gender
# Bachelor             F                              5752.49
#                      M                              5797.38
# College              F                              5642.60
#                      M                              6005.85
# Doctor               F                              5789.85
#                      M                              5843.99
# High School or Below F                              5978.75
#                      M                              6081.48
# Master               F                              5714.17
#                      M                              5512.34

# %%
# 5. Find the maximum, minimum, and average number of open complaints by state and policy type.

df5 = df.groupby(['state','policy_type']).agg({'number_of_open_complaints':['max','min','mean']}).round(2)

df5
# Out:
#                           number_of_open_complaints
#                                                 max  min  mean
# state      policy_type
# Arizona    Corporate Auto                       5.0  0.0  0.46
#            Personal Auto                        5.0  0.0  0.41
#            Special Auto                         3.0  0.0  0.23
# California Corporate Auto                       4.0  0.0  0.30
#            Personal Auto                        5.0  0.0  0.40
#            Special Auto                         4.0  0.0  0.39
# Nevada     Corporate Auto                       3.0  0.0  0.39
#            Personal Auto                        5.0  0.0  0.42
#            Special Auto                         3.0  0.0  0.29
# Oregon     Corporate Auto                       4.0  0.0  0.33
#            Personal Auto                        5.0  0.0  0.37
#            Special Auto                         5.0  0.0  0.33
# Washington Corporate Auto                       4.0  0.0  0.47
#            Personal Auto                        5.0  0.0  0.41
#            Special Auto                         4.0  0.0  0.56

# %%
# 6. The marketing team wants to analyze the number of policies sold by state and month.
# Present the data in a table where the months are arranged as columns and the states are arranged as rows.

df6 = df.groupby(['state','effective_to_date_month']).agg({'customer':'count'}).rename(columns={'customer':'policies_sold'})

df6 = df6.pivot_table( index=['state'], columns=['effective_to_date_month'], values = 'policies_sold')

df6
# Out:
# effective_to_date_month    1    2
# state
# Arizona                  453  415
# California               826  726
# Nevada                   247  197
# Oregon                   676  605
# Washington               207  191

# %%
# 7. Display a new DataFrame that contains the number of policies sold by month by state for the top 3 states 
# with the highest number of policies sold.
'''
Hint:
To accomplish this, you will first need to group the data by state and month, 
then count the number of policies sold for each group. Afterwards, you will need 
to sort the data by the count of policies sold in descending order.
Next, you will select the top 3 states with the highest number of policies sold.
Finally, you will create a new DataFrame that contains the number of policies 
sold by month for each of the top 3 states.
'''

top_3_states = df.groupby(['state']).agg({'customer':'count'}).rename(columns={'customer':'policies_sold'}).sort_values('policies_sold', ascending = False).iloc[:3,-1]

df7 = df[ df['state'].isin(list(top_3_states.index))].groupby(['effective_to_date_month','state']).agg({'customer':'count'}).rename(columns={'customer':'policies_sold'}).sort_values(['effective_to_date_month','policies_sold'], ascending=[True,False])

df7
# Out:
#                                     policies_sold
# effective_to_date_month state
# 1                       California            826
#                         Oregon                676
#                         Arizona               453
# 2                       California            726
#                         Oregon                605
#                         Arizona               415

# %%
# 8. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
# Hint: You can use melt to unpivot the data and create a table that 
# shows the customer response rate (those who responded "Yes") by marketing channel.

df8 = df.groupby(['sales_channel','response']).agg({'response':'count'}).rename(columns={'response':'total'})

df8_pivot = pd.pivot_table(df8.reset_index(), values='total', index ='sales_channel', columns='response')

df8_pivot['response_rate'] = (df8_pivot['Yes'] / df8_pivot['No'] * 100).round(1)

display(df8_pivot)
# Out:
# response         No  Yes  response_rate
# sales_channel
# Agent          1419  332           23.4
# Branch         1123  123           11.0
# Call Center     786   97           12.3
# Web             574   89           15.5
